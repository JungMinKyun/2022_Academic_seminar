# %%
cd '/content/drive/MyDrive/2022/학술제 폴더/카드사기 탐지/2022_Academic_seminar'

# %%
# !git remote rm origin

# %%
# !echo "# 2022_Academic_seminar" >> README.md
# !git init
# !git config --global user.email "minkyun0418@gmail.com"
# !git config --global user.name "JungMinKyun"
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://JungMinKyun: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@github.com/JungMinKyun/2022_Academic_seminar.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/2022/학술제 폴더/카드사기 탐지/2022_Academic_seminar/.git/
# [main fb1d05e] first commit
#  1 file changed, 1 deletion(-)
# error: remote origin already exists.
# To https://github.com/JungMinKyun/2022_Academic_seminar.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/JungMinKyun/2022_Academic_seminar.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# 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

# %%
# !git add .
# !git commit -m "setup"
# !git push
# Out:
# [main 737763e] setup
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enumerating objects: 23, done.
# Counting objects: 100% (23/23), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (21/21), done.
# error: RPC failed; HTTP 408 curl 22 The requested URL returned error: 408
# send-pack: unexpected disconnect while reading sideband packet
# Writing objects: 100% (22/22), 67.19 MiB | 3.54 MiB/s, done.
# Total 22 (delta 8), reused 0 (delta 0), pack-reused 0
# fatal: the remote end hung up unexpectedly
# Everything up-to-date
